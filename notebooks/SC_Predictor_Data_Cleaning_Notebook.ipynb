# %% [markdown]
# # Imports

# %%
import pandas as pd 
import json
import os
import numpy as np
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import punkt
import nltk
from nltk import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from nltk.stem import WordNetLemmatizer 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import recall_score, accuracy_score, confusion_matrix
import string
from nltk.probability import FreqDist
import seaborn as sns
pd.options.display.max_rows = 999
pd.options.display.max_columns = 30
import lexnlp as lnlp
import importlib
import src
from src import *
importlib.reload(src)
# %matplotlib inline

# %% [markdown]
# # Going from JSON Files to a Useable DataFrame

# %% [markdown]
# Here I'm just checking out the case to see what it looks like and making sure I have a good grasp of the file path.

# %%
f = open('../data/supreme-court-cases/cases/1956/Achilli_v._United_States.js')
# it goes data, the repo, cases, year, then the name of the case
data = json.load(f)

# %% [markdown]
# ## Making a List of the File Paths for each Case

# %% [markdown]
# Now Im going to loop through all the cases and append each ones name to the file path that will give me access to it.

# %%
# adding the years as the second level
ls_years = []
for x in range(1956, 2018):
    ls_years.append(x)
file_paths = []
for x in ls_years:
    file_paths.append(f'../data/supreme-court-cases/cases/{x}')

# %%
#making the list of case names
cases = {} 
for x in range(0, len(ls_years)):
    json_files = [pos_json for pos_json in os.listdir(file_paths[x]) if pos_json.endswith('.js')]
    cases.update({ls_years[x]: json_files})

# %%
#and opening all the cases with the filepaths and appending them to to a list 
case_list = []
for x in ls_years:
    for case in cases[x]: 
        f = open(f'../data/supreme-court-cases/cases/{x}/{case}') 
        data = json.load(f)
        case_list.append(data)

# %% [markdown]
# ## Grabbing Just the Transcripts

# %% [markdown]
# Nested further within the list is the case transcript which is what we need for this project.

# %%
transcript_dict = {}# making a dictionary with the citation of the case as the key and the transcript as each entry 
for x in range(0, len(case_list)):
    try:
        transcript_dict.update({case_list[x]['citation']: case_list[x]['caseTranscripts'][0]['transcript']})
    except:
        pass

# %% [markdown]
# ## Further Organazing the Transcripts

# %% [markdown]
# Here I made a list of dictionarys, each one is a case, and each dictionary has a speaker as its key and the transcript of what they said as its value.

# %%
speaker_cleanText = {} #Now I need to segment the transcripts further by speaker
for case in transcript_dict.keys(): #"clean text" is a path within the json wich has their words in a cleaner format
    ls= []
    for x in transcript_dict[case]:
        ls.append([x['speakerName'].lower(), [x['textObjs'][y]['cleanText'] for y in range(0, len(x['textObjs']))]])
    speaker_cleanText.update({case: ls})

# %%
for case in speaker_cleanText: #quickly getting rid of some punctation so I can filter through different names easily
    for x in range(0,len(speaker_cleanText[case])):
        speaker_cleanText[case][x][0] = speaker_cleanText[case][x][0].lower().replace(" ", "").replace('.', '').replace(',','').replace('jr','')

# %%
speaker_cleanText['353 US 373 (1957)'] # Testing out the dictionary and discerning the list format
# Out:
# [['charleskrice',
#   [[['I',
#      'be',
#      'include',
#      'my',
#      'remark',
#      'with',
#      'respect',
#      'to',
#      'the',
#      'inaudible',
#      'the',
#      'application',
#      'of']],
#    [['i',
#      'think',
#      'it',
#      'be',
#      'fair',
#      'to',
#      'say',
#      'that',
#      'the',
#      'purpose',
#      'apply',
#      'that',
#      'particular',
#      'section',
#      'we',
#      'be',
#      'to',
#      'to',
#      'meet',
#      'the',
#      'protest',
#      'of',
#      'the',
#      'district',
#      'court',
#      'the',
#      'various',
#      'district',
#      'court',
#      'and',
#      'the',
#      'united',
#      'state',
#      'attorney',
#      'in',
#      'the',
#      'various',
#      'district']],
#    [['and',
#      'to',
#      'ameliorate',
#      'a',
#      'lot',
#      'of',
#      'the',
#      'small',
#      'taxpayer',
#      'who',
#      'be',
#      'be',
#      'subject',
#      'to',
#      'a',
#      'felony',
#      'prosecution',
#      'and',
#      'summons',
#      'where',
#      'the',
#      'tax',
#      'involve',
#      'be',
#      'as',
#      'low',
#      'as',
#      'a',
#      'or',
#      'a']]]],
#  ['hugolblack',
#   [[['you',
#      'i',
#      'suppose',
#      'have',
#      'put',
#      'in',
#      'your',
#      'brief',
#      'the',
#      'name',
#      'of',
#      'those',
#      'case',
#      'and',
#      'the',
#      'amount',
#      'involve',
#      'in',
#      'them',
#      'substantially',
#      'to',
#      'the',
#      'statement']]]],
#  ['charleskrice',
#   [[['no', 'your', 'honor']],
#    [['we', 'have', 'not', 'get', 'the', 'name', 'of', 'the', 'case']],
#    [['we',
#      'have',
#      'a',
#      'reference',
#      'of',
#      'the',
#      'total',
#      'amount',
#      'of',
#      'the',
#      'case']],
#    [['they', 'have', 'the', 'list', 'of', 'the', 'amount', 'involve']]]],
#  ['hugolblack',
#   [[['if',
#      'this',
#      'be',
#      'material',
#      'i',
#      'should',
#      'think',
#      'might',
#      'be',
#      'wise',
#      'to',
#      'have',
#      'all',
#      'record',
#      'of',
#      'all',
#      'those',
#      'case',
#      'during',
#      'that',
#      'period',
#      'of',
#      'time',
#      'with',
#      'the',
#      'name',
#      'where',
#      'they',
#      'we',
#      'be',
#      'try']]]],
#  ['charleskrice', [[['oh', 'we', 'could', 'give', 'you']]]],
#  ['hugolblack',
#   [[['if',
#      'i',
#      'presume',
#      'it',
#      'would',
#      'be',
#      'very',
#      'easy',
#      'because',
#      'you',
#      'know']]]],
#  ['charleskrice',
#   [[['yes']],
#    [['we',
#      'could',
#      'give',
#      'you',
#      'the',
#      'i',
#      'think',
#      'that',
#      'we',
#      'can',
#      'state',
#      'it',
#      'as',
#      'a',
#      'general',
#      'proposition',
#      'that',
#      'those',
#      'prosecution',
#      'involve',
#      'less',
#      'than',
#      'a',
#      'in',
#      'income']]]],
#  ['hugolblack', [[['i', 'think', 'you', 'say', 'less', 'than', 'hundred']]]],
#  ['charleskrice', [[['that', 'be', 'tax', 'sir']]]],
#  ['hugolblack', [[['tax']]]],
#  ['charleskrice',
#   [[['less',
#      'than',
#      'a',
#      'in',
#      'income',
#      'and',
#      'of',
#      'course',
#      'considerably',
#      'below',
#      'that',
#      'in',
#      'tax']]]],
#  ['hugolblack', [[['that', 'be', 'all', 'of', 'them']]]],
#  ['charleskrice',
#   [[['well',
#      'i',
#      'would',
#      'not',
#      'want',
#      'to',
#      'say',
#      'that',
#      'there',
#      'never',
#      'have',
#      'be',
#      'an',
#      'exception',
#      'to',
#      'that',
#      'but',
#      'that',
#      'have',
#      'be',
#      'the',
#      'general',
#      'practice']],
#    [['and',
#      'as',
#      'far',
#      'as',
#      'the',
#      'amount',
#      'involve',
#      'i',
#      'have',
#      'not',
#      'actually',
#      'make',
#      'a',
#      'study',
#      'of',
#      'the',
#      'case',
#      'myself',
#      'to',
#      'determine',
#      'whether',
#      'it',
#      'be',
#      'a',
#      'or',
#      'or',
#      'or',
#      'but',
#      'i',
#      'think',
#      'i',
#      'can',
#      'fairly',
#      'say',
#      'and',
#      'we',
#      'will',
#      'be',
#      'glad',
#      'to',
#      'furnish',
#      'whatever',
#      'he',
#      'would',
#      'like',
#      'in',
#      'that',
#      'respect',
#      'that',
#      'the',
#      'amount',
#      'involve',
#      'we',
#      'be',
#      'not',
#      'large']]]],
#  ['felixfrankfurter',
#   [[['but',
#      'if',
#      'you',
#      'if',
#      'you',
#      'be',
#      'right',
#      'in',
#      'your',
#      'present',
#      'position',
#      'then',
#      'no',
#      'matter',
#      'how',
#      'small',
#      'they',
#      'would',
#      'all',
#      'have',
#      'the',
#      'prosecution',
#      'would',
#      'all',
#      'have',
#      'to',
#      'be',
#      'begin',
#      'by',
#      'before',
#      'a',
#      'grand',
#      'jury',
#      'and',
#      'by',
#      'indictment']]]],
#  ['charleskrice',
#   [[['that',
#      'be',
#      'correct',
#      'your',
#      'honor',
#      'if',
#      'have',
#      'no',
#      'application',
#      'in',
#      'this',
#      'area']]]],
#  ['earlwarren',
#   [[['well',
#      'would',
#      'that',
#      'would',
#      'those',
#      'figure',
#      'after',
#      'they',
#      'reflect',
#      'the',
#      'amount',
#      'of',
#      'the',
#      'tax',
#      'that',
#      'have',
#      'be',
#      'evade',
#      'or',
#      'or',
#      'would',
#      'they',
#      'be',
#      'do',
#      'as',
#      'they',
#      'sometimes',
#      'do',
#      'in',
#      'other',
#      'case',
#      'say',
#      'in',
#      'an',
#      'embezzlement',
#      'case',
#      'where',
#      'have',
#      'be',
#      'embezzle',
#      'maybe',
#      'they',
#      'will',
#      'only',
#      'charge',
#      'a',
#      'or',
#      'because',
#      'those',
#      'item',
#      'be',
#      'clear',
#      'to',
#      'make',
#      'that',
#      'voice',
#      'overlap']]]],
#  ['charleskrice',
#   [[['yes']],
#    [['well',
#      'that',
#      'i',
#      'think',
#      'be',
#      'true',
#      'in',
#      'almost',
#      'every',
#      'criminal',
#      'tax',
#      'case']]]],
#  ['earlwarren', [[['yes']]]],
#  ['charleskrice',
#   [[['not',
#      'every',
#      'case',
#      'but',
#      'in',
#      'most',
#      'of',
#      'them',
#      'you',
#      'have',
#      'what',
#      'they',
#      'call',
#      'the',
#      'prosecutor',
#      'of',
#      'the',
#      'net',
#      'income',
#      'for',
#      'prosecution',
#      'purpose',
#      'and',
#      'that',
#      'be',
#      'very',
#      'frequently',
#      'less',
#      'than',
#      'but',
#      'for',
#      'civil',
#      'what',
#      'they',
#      'would',
#      'allege',
#      'for',
#      'civil',
#      'purpose']],
#    [['so',
#      'what',
#      'I',
#      'be',
#      'talk',
#      'about',
#      'be',
#      'the',
#      'amount',
#      'allege',
#      'for',
#      'criminal',
#      'purpose']],
#    [['now',
#      'a',
#      'very',
#      'large',
#      'percentage',
#      'of',
#      'these',
#      'small',
#      'case',
#      'where',
#      'the',
#      'result',
#      'of',
#      'the',
#      'claim',
#      'of',
#      'a',
#      'fictitious',
#      'defendant',
#      'where',
#      'a',
#      'person',
#      'would',
#      'claim',
#      'that',
#      'john',
#      'jones',
#      'and',
#      'richard',
#      'rowe',
#      'we',
#      'be',
#      'defendant',
#      'when',
#      'actually',
#      'there',
#      'be',
#      'no',
#      'such',
#      'person',
#      'as',
#      'john',
#      'jones',
#      'or',
#      'richard',
#      'rowe']],
#    [['and',
#      'the',
#      'amount',
#      'of',
#      'the',
#      'exemption',
#      'be',
#      'for',
#      'each',
#      'of',
#      'them',
#      'and',
#      'would',
#      'result',
#      'in',
#      'a',
#      'fairly',
#      'small',
#      'tax',
#      'and',
#      'yet',
#      'the',
#      'fraud',
#      'would',
#      'be',
#      'so',
#      'clear',
#      'cut',
#      'that',
#      'it',
#      'be',
#      'difficult',
#      'to',
#      'overlook',
#      'at']]]],
#  ['williamjbrennan', [[['do', 'you', 'say']]]],
#  ['charleskrice',
#   [[['so',
#      'that',
#      'the',
#      'the',
#      'purpose',
#      'in',
#      'bring',
#      'these',
#      'prosecution',
#      'under',
#      'section',
#      'be',
#      'i',
#      'think',
#      'to']]]],
#  ['hugolblack', [[['be', 'that', 'material', 'here']]]],
#  ['charleskrice', [[['well']]]],
#  ['hugolblack',
#   [[['if',
#      'it',
#      'be',
#      'material',
#      'i',
#      'think',
#      'if',
#      'you',
#      'be',
#      'go',
#      'to',
#      'state',
#      'that',
#      'they',
#      'be',
#      'all',
#      'small',
#      'and',
#      'but',
#      'the',
#      'purpose',
#      'be',
#      'it',
#      'would',
#      'be',
#      'wise',
#      'if',
#      'you',
#      'give',
#      'us',
#      'a',
#      'list',
#      'because',
#      'i',
#      'do',
#      'not',
#      'think',
#      'it',
#      'be',
#      'material']],
#    [['but',
#      'if',
#      'it',
#      'be',
#      'material',
#      'i',
#      'think',
#      'we',
#      'should',
#      'be',
#      'give',
#      'a',
#      'list']]]],
#  ['charleskrice',
#   [[['well',
#      'i',
#      'do',
#      'not',
#      'think',
#      'it',
#      'be',
#      'material',
#      'either',
#      'your',
#      'honor']]]],
#  ['hugolblack', [[['not', 'in', 'the', 'general', 'sense', 'but', 'all']]]],
#  ['charleskrice',
#   [[['i', 'do', 'not', 'think', 'it', 'be', 'material', 'either']],
#    [['what',
#      'I',
#      'be',
#      'say',
#      'here',
#      'be',
#      'by',
#      'way',
#      'of',
#      'background',
#      'as',
#      'to',
#      'how',
#      'the',
#      'department',
#      'get',
#      'embark',
#      'on',
#      'this',
#      'particular',
#      'course',
#      'of',
#      'action']]]],
#  ['williamjbrennan',
#   [[['number',
#      'of',
#      'these',
#      'case',
#      'i',
#      'think',
#      'you',
#      'tell',
#      'us',
#      'before',
#      'recess',
#      'where',
#      'prosecute',
#      'by',
#      'information',
#      'of',
#      'an',
#      'indictment']]]],
#  ['charleskrice',
#   [[['yes']],
#    [['i',
#      'would',
#      'say',
#      'the',
#      'majority',
#      'of',
#      'them',
#      'the',
#      'large',
#      'majority',
#      'of',
#      'them',
#      'there',
#      'we',
#      'be',
#      'of',
#      'course',
#      'some',
#      'by',
#      'indictment']]]],
#  ['williamjbrennan',
#   [[['with',
#      'this',
#      'new',
#      'position',
#      'the',
#      'government',
#      'be',
#      'correct',
#      'what',
#      'be',
#      'the',
#      'government',
#      's',
#      'position',
#      'in',
#      'relation',
#      'to',
#      'people',
#      'prosecute',
#      'by',
#      'and',
#      'large']],
#    [['now', 'it', 'should', 'not', 'have', 'be', 'prosecute', 'at', 'all']]]],
#  ['charleskrice',
#   [[['well',
#      'of',
#      'course',
#      'that',
#      'question',
#      'be',
#      'not',
#      'decide',
#      'as',
#      'yet',
#      'whether',
#      'or',
#      'not',
#      'they',
#      'should',
#      'have',
#      'be',
#      'prosecute',
#      'at',
#      'all']],
#    [['we', 'do', 'not', 'have', 'before', 'us', 'a', 'section', 'case']],
#    [['now',
#      'in',
#      'conclude',
#      'these',
#      'these',
#      'remark',
#      'with',
#      'respect',
#      'to',
#      'i',
#      'think',
#      'i',
#      'should',
#      'say',
#      'that',
#      'whether',
#      'or',
#      'not',
#      'the',
#      'government',
#      'proceed',
#      'correctly',
#      'under',
#      'the',
#      'section',
#      'it',
#      'invoke',
#      'as',
#      'a',
#      'matter',
#      'that',
#      'we',
#      'just',
#      'do',
#      'not',
#      'know',
#      'or',
#      'prosecution',
#      'under',
#      'that',
#      'section',
#      'have',
#      'be',
#      'hold',
#      'in',
#      'advance',
#      'pending',
#      'the',
#      'outcome',
#      'of',
#      'this',
#      'proceeding']],
#    [['and',
#      'as',
#      'far',
#      'as',
#      'this',
#      'case',
#      'be',
#      'concern',
#      'it',
#      'be',
#      'a',
#      'b',
#      'case',
#      'and',
#      'we',
#      'think',
#      'that',
#      'the',
#      'issue',
#      'as',
#      'to',
#      'a',
#      'case',
#      'ought',
#      'to',
#      'be',
#      'resolve',
#      'when',
#      'such',
#      'a',
#      'case',
#      'come',
#      'before',
#      'this',
#      'court']]]],
#  ['hugolblack',
#   [[['well',
#      'it',
#      'be',
#      'just',
#      'the',
#      'same',
#      'i',
#      'would',
#      'not',
#      'decide',
#      'on',
#      'that',
#      'basis',
#      'that',
#      'a',
#      'do',
#      'apply',
#      'to',
#      'income',
#      'tax',
#      'case']],
#    [['that',
#      'this',
#      'man',
#      'could',
#      'have',
#      'be',
#      'prosecute',
#      'under',
#      'either']]]],
#  ['charleskrice',
#   [[['well',
#      'there',
#      'again',
#      'that',
#      'question',
#      'be',
#      'not',
#      'before',
#      'the',
#      'court',
#      'because',
#      'he',
#      'be',
#      'prosecute',
#      'under',
#      'section',
#      'b']]]],
#  ['hugolblack', [[['i', 'understand', 'he', 'we', 'be']]]],
#  ['felixfrankfurter',
#   [[['but',
#      'if',
#      'your',
#      'i',
#      'do',
#      'not',
#      'know',
#      'what',
#      'i',
#      'do',
#      'not',
#      'i',
#      'do',
#      'not',
#      'quite',
#      'appreciate',
#      'your',
#      'answer']],
#    [['if',
#      'the',
#      'position',
#      'now',
#      'take',
#      'by',
#      'the',
#      'government',
#      'be',
#      'correct',
#      'then',
#      'you',
#      'then',
#      'your',
#      'answer',
#      'to',
#      'justice',
#      'black',
#      's',
#      'question',
#      'be',
#      'he',
#      'could',
#      'not',
#      'be',
#      'prosecute',
#      'in',
#      'the',
#      'and',
#      'he',
#      'be',
#      'properly',
#      'prosecute',
#      'by',
#      'the',
#      'only',
#      'section',
#      'under',
#      'which',
#      'he',
#      'could',
#      'be',
#      'prosecute',
#      'b']],
#    [['be', 'that', 'correct']]]],
#  ['charleskrice',
#   [[['well', 'i', 'think', 'that', 'be', 'correct']],
#    [['of', 'course', 'in', 'the', 'moran', 'case', 'be', 'the']]]],
#  ['hugolblack',
#   [[['you', 'mean', 'if', 'your', 'position', 'be', 'correct']]]],
#  ['charleskrice', [[['yes']]]],
#  ['felixfrankfurter', [[['that', 'be', 'my', 'hypothesis']]]],
#  ['hugolblack',
#   [[['yes']],
#    [['and', 'suppose', 'your', 'position', 'be', 'wrong']],
#    [['and', 'suppose', 'that', 'both', 'statute', 'apply']],
#    [['we',
#      'do',
#      'not',
#      'understand',
#      'what',
#      'you',
#      'say',
#      'on',
#      'page',
#      'that',
#      'in',
#      'this',
#      'case',
#      'as',
#      'in',
#      'berra',
#      'and',
#      'that',
#      'prove',
#      'that',
#      'he',
#      'willfully',
#      'attempt',
#      'to',
#      'raise',
#      'by',
#      'file',
#      'a',
#      'false',
#      'return',
#      'as',
#      'identical',
#      'of',
#      'that',
#      'required',
#      'prove',
#      'that',
#      'he',
#      'file',
#      'a',
#      'false',
#      'return',
#      'with',
#      'attempt',
#      'to',
#      'evade',
#      'in',
#      'violation',
#      'of']],
#    [['that', 'be', 'what', 'the', 'government', 'argue', 'in', 'berra']]]],
#  ['felixfrankfurter',
#   [[['yes']],
#    [['well',
#      'your',
#      'honor',
#      'we',
#      'have',
#      'a',
#      'question',
#      'here',
#      'as',
#      'to',
#      'whether',
#      'the',
#      'there',
#      'be',
#      'one',
#      'or',
#      'two',
#      'offense',
#      'involve']],
#    [['now',
#      'the',
#      'language',
#      'of',
#      'the',
#      'second',
#      'circuit',
#      'in',
#      'the',
#      'moran',
#      'case',
#      'would',
#      'seem',
#      'to',
#      'imply',
#      'that',
#      'there',
#      'be',
#      'two',
#      'offense',
#      'involve',
#      'here',
#      'because',
#      'each',
#      'of',
#      'the',
#      'section',
#      'require',
#      'proof',
#      'of',
#      'an',
#      'act',
#      'which',
#      'be',
#      'not',
#      'require',
#      'for',
#      'the',
#      'other']],
#    [['but',
#      'we',
#      'think',
#      'that',
#      'you',
#      'do',
#      'not',
#      'have',
#      'to',
#      'resolve',
#      'that',
#      'question',
#      'because',
#      'even',
#      'if',
#      'there',
#      'be',
#      'only',
#      'one',
#      'offense',
#      'here',
#      'involve',
#      'here',
#      'we',
#      'think',
#      'there',
#      'be',
#      'nothing',
#      'to',
#      'preclude',
#      'the',
#      'court',
#      'from',
#      'apply',
#      'under',
#      'from',
#      'proceed',
#      'under',
#      'the',
#      'felony',
#      'statute',
#      'as',
#      'against',
#      'the',
#      'misdemeanor',
#      'statute']]]],
#  ['felixfrankfurter',
#   [[['if',
#      'if',
#      'there',
#      'there',
#      'be',
#      'two',
#      'offense',
#      'when',
#      'there',
#      'be',
#      'no',
#      'problem',
#      'of',
#      'choice',
#      'by',
#      'a',
#      'prosecutor',
#      'with',
#      'different',
#      'term',
#      'be',
#      'there']]]],
#  ['charleskrice',
#   [[['well',
#      'we',
#      'we',
#      'all',
#      'think',
#      'of',
#      'it',
#      'in',
#      'term',
#      'of',
#      'choice',
#      'for',
#      'the',
#      'prosecutor',
#      'your',
#      'honor']]]],
#  ['felixfrankfurter',
#   [[['well',
#      'i',
#      'do',
#      'not',
#      'i',
#      'do',
#      'not',
#      'mean',
#      'to',
#      'say',
#      'but',
#      'the',
#      'problem',
#      'do',
#      'not',
#      'arise']]]],
#  ['charleskrice', [[['yes']], [['that', 'be', 'correct', 'your', 'honor']]]],
#  ['felixfrankfurter',
#   [[['all', 'right']], [['i', 'know', 'that', 'you', 'do', 'not']]]],
#  ['hugolblack',
#   [[['the',
#      'question',
#      'i',
#      'be',
#      'ask',
#      'be',
#      'in',
#      'the',
#      'berra',
#      'case',
#      'the',
#      'government',
#      's',
#      'brief',
#      'say',
#      'this',
#      'as',
#      'i',
#      'quote',
#      'it',
#      'to',
#      'the',
#      'oral',
#      'argument']],
#    [['section',
#      'b',
#      'a',
#      'overlap',
#      'a',
#      'broad',
#      'area',
#      'illustrate',
#      'by',
#      'the',
#      'present',
#      'case']],
#    [['be', 'that', 'prove', 'here']]]],
#  ['charleskrice', [[['where', 'be', 'you', 'read', 'from']]]],
#  ['hugolblack',
#   [[['i',
#      'be',
#      'read',
#      'from',
#      'the',
#      'government',
#      's',
#      'brief',
#      'in',
#      'the',
#      'berra',
#      'case']],
#    [['be',
#      'that',
#      'true',
#      'here',
#      'what',
#      'the',
#      'government',
#      'say',
#      'about',
#      'the',
#      'berra',
#      'case']]]],
#  ['charleskrice',
#   [[['well',
#      'it',
#      'be',
#      'true',
#      'to',
#      'the',
#      'extent',
#      'that',
#      'you',
#      'have',
#      'two',
#      'offense',
#      'which',
#      'the',
#      'same',
#      'act',
#      'could',
#      'violate']]]],
#  ['hugolblack',
#   [[['well',
#      'do',
#      'do',
#      'this',
#      'act',
#      'in',
#      'this',
#      'case',
#      'if',
#      'you',
#      'be',
#      'wrong',
#      'and',
#      'if',
#      'you',
#      'can',
#      'prosecute',
#      'under',
#      'either',
#      'be',
#      'there',
#      'search',
#      'to',
#      'justify',
#      'a',
#      'prosecution',
#      'under',
#      'both']]]],
#  ['charleskrice',
#   [[['well',
#      'your',
#      'honor',
#      'our',
#      'position',
#      'be',
#      'that',
#      'you',
#      'do',
#      'not',
#      'have',
#      'to',
#      'decide',
#      'that',
#      'question']]]],
#  ['hugolblack',
#   [[['i',
#      'understand',
#      'that',
#      'but',
#      'maybe',
#      'we',
#      'might',
#      'disagree',
#      'with',
#      'that']],
#    [['suppose',
#      'we',
#      'do',
#      'be',
#      'we',
#      'to',
#      'try',
#      'it',
#      'on',
#      'the',
#      'basis',
#      'that',
#      'if',
#      'and',
#      'a',
#      'apply',
#      'these',
#      'overlap',
#      'as',
#      'we',
#      'would',
#      'say',
#      'in',
#      'the',
#      'case',
#      'and',
#      'the',
#      'berra',
#      'case']]]],
#  ['charleskrice', [[['well', 'i', 'think', 'that']]]],
#  ['hugolblack', [[['under', 'the', 'fact']]]],
#  ['charleskrice',
#   [[['i',
#      'just',
#      'can',
#      'not',
#      'say',
#      'as',
#      'to',
#      'what',
#      'would',
#      'be',
#      'do',
#      'in',
#      'that',
#      'situation']],
#    [['it', 'have', 'not', 'be', 'do', 'in', 'the', 'past']],
#    [['there', 'have', 'not', 'be', 'prosecution', 'under', 'both', 'section']],
#    [['i',
#      'think',
#      'it',
#      'be',
#      'highly',
#      'unlikely',
#      'there',
#      'would',
#      'be']]]],
#  ['hugolblack',
#   [[['i',
#      'do',
#      'not',
#      'ask',
#      'i',
#      'do',
#      'not',
#      'ask',
#      'you',
#      'that',
#      'question']],
#    [['there',
#      'be',
#      'a',
#      'very',
#      'simple',
#      'statement',
#      'in',
#      'connection',
#      'with',
#      'the',
#      'berra',
#      'prosecution',
#      'which',
#      'be',
#      'present',
#      'to',
#      'us',
#      'and',
#      'it',
#      'be',
#      'admit',
#      'by',
#      'the',
#      'government',
#      'that',
#      'under',
#      'the',
#      'fact',
#      'in',
#      'that',
#      'case',
#      'as',
#      'be',
#      'then',
#      'construe',
#      'the',
#      'defendant',
#      'could',
#      'be',
#      'prosecute',
#      'under',
#      'either']],
#    [['be',
#      'that',
#      'the',
#      'case',
#      'here',
#      'with',
#      'reference',
#      'to',
#      'these',
#      'fact']]]],
#  ['charleskrice',
#   [[['well', 'yes']],
#    [['i', 'think', 'it', 'be']],
#    [['in',
#      'other',
#      'word',
#      'when',
#      'we',
#      'bring',
#      'the',
#      'b',
#      'prosecution',
#      'it',
#      'be',
#      'conceivable',
#      'that',
#      'the',
#      'court',
#      'could',
#      'have',
#      'find',
#      'the',
#      'defendant',
#      'guilty',
#      'under']]]],
#  ['hugolblack',
#   [[['be',
#      'it',
#      'conceivable',
#      'or',
#      'be',
#      'it',
#      'your',
#      'judgment',
#      'it',
#      'could']]]],
#  ['charleskrice',
#   [[['it', 'could', 'have']], [['it', 'could', 'have', 'your', 'honor']]]],
#  ['unknown',
#   [[['well',
#      'let',
#      'let',
#      'us',
#      'assume',
#      'that',
#      'the',
#      'two',
#      'statute',
#      'be',
#      'identical',
#      'and',
#      'you',
#      'could',
#      'have',
#      'prosecute',
#      'under',
#      'either',
#      'what',
#      'be',
#      'the',
#      'government',
#      's',
#      'position',
#      'on',
#      'that',
#      'question']]]],
#  ['charleskrice',
#   [[['that', 'we', 'could', 'have', 'prosecute', 'under', 'either']]]],
#  ['unknown', [[['yes']]]],
#  ['charleskrice', [[['well']]]],
#  ['unknown',
#   [[['you', 'could', 'have', 'caption', 'this', 'indictment', 'a', 'or', 'b']],
#    [['now', 'what', 'would']]]],
#  ['charleskrice',
#   [[['well',
#      'we',
#      'believe',
#      'it',
#      'be',
#      'a',
#      'matter',
#      'within',
#      'the',
#      'discretion',
#      'of',
#      'the',
#      'court',
#      'that',
#      'the',
#      'court',
#      'could',
#      'have',
#      'find',
#      'the',
#      'defendant',
#      'guilty',
#      'under',
#      'b',
#      'or',
#      'it',
#      'could',
#      'have',
#      'find',
#      'him',
#      'guilty',
#      'under',
#      'a']],
#    [['not', 'a', 'matter', 'of', 'the', 'prosecutor', 's', 'discretion']]]],
#  ['hugolblack',
#   [[['i',
#      'understood',
#      'you',
#      'to',
#      'say',
#      'that',
#      'the',
#      'washington',
#      'office',
#      'send',
#      'to',
#      'the',
#      'prosecute',
#      'attorney',
#      'in',
#      'case',
#      'we',
#      'be',
#      'make',
#      'about',
#      'this',
#      'one',
#      'inaudible',
#      'case',
#      'with',
#      'instruction',
#      'to',
#      'proceed',
#      'under']]]],
#  ['charleskrice', [[['that', 'be', 'correct']]]],
#  ['hugolblack', [[['but', 'whose', 'choice', 'be', 'that']]]],
#  ['charleskrice',
#   [[['that', 'be', 'the', 'choice', 'of', 'the', 'prosecutor']]]],
#  ['hugolblack',
#   [[['and', 'we', 'be', 'they', 'prosecute', 'by', 'information']]]],
#  ['charleskrice',
#   [[['well', 'i', 'think', 'that', 'most', 'of', 'them', 'we', 'be']]]],
#  ['hugolblack', [[['who', 'make', 'those', 'choice']]]],
#  ['charleskrice',
#   [[['there',
#      'there',
#      'we',
#      'be',
#      'really',
#      'some',
#      'that',
#      'be',
#      'make',
#      'by',
#      'the',
#      'department',
#      'by',
#      'the',
#      'prosecutor']]]],
#  ['felixfrankfurter',
#   [[['your',
#      'main',
#      'position',
#      'however',
#      'as',
#      'i',
#      'understand',
#      'it',
#      'and',
#      'to',
#      'me',
#      'it',
#      'be',
#      'very',
#      'important',
#      'to',
#      'determine',
#      'whether',
#      'its',
#      'own',
#      'act']],
#    [['your',
#      'main',
#      'position',
#      'be',
#      'that',
#      'a',
#      'detailed',
#      'consideration',
#      'which',
#      'we',
#      'not',
#      'yet',
#      'have',
#      'at',
#      'the',
#      'legislative',
#      'history',
#      'of',
#      'the',
#      'criminal',
#      'enforcement',
#      'of',
#      'the',
#      'income',
#      'tax']],
#    [['the',
#      'government',
#      'demonstrate',
#      'b',
#      'as',
#      'exclusive',
#      'the',
#      'do',
#      'not',
#      'apply',
#      'to',
#      'it']],
#    [['be', 'that', 'right']]]],
#  ['charleskrice', [[['that', 'be', 'right', 'your', 'honor']]]],
#  ['felixfrankfurter',
#   [[['well',
#      'i',
#      'think',
#      'it',
#      'be',
#      'very',
#      'important',
#      'too',
#      'this',
#      'be',
#      'a',
#      'new',
#      'position']],
#    [['and',
#      'for',
#      'me',
#      'nothing',
#      'have',
#      'happen',
#      'on',
#      'the',
#      'fact',
#      'that',
#      'stop',
#      'take',
#      'that',
#      'position']],
#    [['it',
#      'be',
#      'never',
#      'too',
#      'late',
#      'to',
#      'find',
#      'out',
#      'what',
#      'congress',
#      'really',
#      'do']]]],
#  ['charleskrice', [[['well', 'i', 'think']]]],
#  ['hugolblack',
#   [[['i',
#      'do',
#      'not',
#      'suppose',
#      'i',
#      'do',
#      'not',
#      'suppose',
#      'it',
#      'be',
#      'too',
#      'late',
#      'for',
#      'any',
#      'of',
#      'us',
#      'to',
#      'do',
#      'that']],
#    [['i',
#      'simply',
#      'want',
#      'to',
#      'find',
#      'out',
#      'first',
#      'if',
#      'we',
#      'disagree',
#      'with',
#      'your',
#      'position',
#      'if',
#      'these',
#      'we',
#      'be',
#      'the',
#      'same',
#      'kind',
#      'of',
#      'case',
#      'as',
#      'the',
#      'berra',
#      'case']],
#    [['of',
#      'course',
#      'if',
#      'you',
#      'be',
#      'wrong',
#      'all',
#      'that',
#      'time',
#      'and',
#      'the',
#      'do',
#      'not',
#      'cover',
#      'income',
#      'tax',
#      'it',
#      'should',
#      'not',
#      'be',
#      'hold',
#      'cover',
#      'if',
#      'it',
#      'do',
#      'not',
#      'do',
#      'it']]]],
#  ['felixfrankfurter',
#   [[['as',
#      'many',
#      'often',
#      'we',
#      'would',
#      'leave',
#      'enough',
#      'time',
#      'for',
#      'the',
#      'main',
#      'problem',
#      'that',
#      'the',
#      'government',
#      'have',
#      'now',
#      'present',
#      'which',
#      'be',
#      'very',
#      'foreign',
#      'to',
#      'me']]]],
#  ['hugolblack',
#   [[['I',
#      'be',
#      'delighted',
#      'to',
#      'see',
#      'that',
#      'be',
#      'reproduce',
#      'for',
#      'counsel',
#      'this',
#      'time']]]],
#  ['felixfrankfurter',
#   [[['it',
#      'be',
#      'with',
#      'my',
#      'information',
#      'at',
#      'the',
#      'counsel',
#      's',
#      'time',
#      'for',
#      'my',
#      'enlightenment']],
#    [['that',
#      'be',
#      'what',
#      'counsel',
#      'be',
#      'here',
#      'for',
#      'to',
#      'enlighten',
#      'the',
#      'court',
#      'not',
#      'to',
#      'be',
#      'indulge',
#      'to',
#      'be',
#      'indulge',
#      'it']]]],
#  ['charleskrice',
#   [[['well',
#      'your',
#      'honor',
#      'with',
#      'respect',
#      'to',
#      'the',
#      'legislative',
#      'history',
#      'of',
#      'section',
#      'a',
#      'section',
#      'which',
#      'state',
#      'back',
#      'which',
#      'date',
#      'back',
#      'to',
#      'our',
#      'research',
#      'have',
#      'indicate',
#      'there',
#      'be',
#      'the',
#      'grave',
#      'doubt',
#      'as',
#      'to',
#      'whether',
#      'it',
#      'apply',
#      'or',
#      'contend',
#      'to',
#      'apply',
#      'to',
#      'federal',
#      'income',
#      'tax',
#      'as',
#      'we',
#      'have',
#      'know',
#      'it',
#      'since']],
#    [['now',
#      'back',
#      'in',
#      'the',
#      'civil',
#      'war',
#      'day',
#      'when',
#      'you',
#      'have',
#      'the',
#      'act',
#      'of',
#      'and',
#      'where',
#      'they',
#      'include',
#      'a',
#      'statute',
#      'which',
#      'be',
#      'very',
#      'similar',
#      'to',
#      'within',
#      'the',
#      'act',
#      'itself',
#      'i',
#      'think',
#      'it',
#      'be',
#      'safe',
#      'to',
#      'assume',
#      'that',
#      'that',
#      'act',
#      'do',
#      'apply',
#      'to',
#      'this',
#      'civil',
#      'war',
#      'income',
#      'tax',
#      'which',
#      'do',
#      'not',
#      'have',
#      'any',
#      'other',
#      'sanction',
#      'of',
#      'itself']],
#    [['and',
#      'again',
#      'in',
#      'when',
#      'the',
#      'income',
#      'tax',
#      'law',
#      'be',
#      'pass',
#      'which',
#      'be',
#      'hold',
#      'unconstitutional',
#      'by',
#      'this',
#      'court',
#      'in',
#      'the',
#      'pollock',
#      'against',
#      'farmer',
#      'loan',
#      'trust',
#      'company',
#      'case']],
#    [['there',
#      'again',
#      'we',
#      'have',
#      'no',
#      'sanction',
#      'within',
#      'the',
#      'statute']],
#    [['so',
#      'and',
#      'it',
#      'seem',
#      'fair',
#      'to',
#      'assume',
#      'that',
#      'the',
#      'sanction',
#      'of',
#      'section',
#      'have',
#      'become',
#      'in',
#      'of',
#      'the',
#      'revise',
#      'statute',
#      'be',
#      'intend',
#      'to',
#      'be',
#      'the',
#      'specific',
#      'sanction',
#      'which',
#      'would',
#      'apply',
#      'to',
#      'that',
#      'particular',
#      'act']],
#    [['but',
#      'when',
#      'we',
#      'come',
#      'down',
#      'to',
#      'the',
#      'war',
#      'revenue',
#      'act',
#      'of',
#      'which',
#      'we',
#      'be',
#      'not',
#      'an',
#      'income',
#      'tax',
#      'law',
#      'but',
#      'a',
#      'general',
#      'revenue',
#      'act',
#      'that',
#      'act',
#      'have',
#      'specific',
#      'penalty',
#      'and',
#      'it',
#      'provide',
#      'that',
#      'if',
#      'any',
#      'manufacturer',
#      'or',
#      'maker',
#      'make',
#      'a',
#      'false',
#      'run',
#      'through',
#      'declaration',
#      'he',
#      'shall',
#      'be',
#      'guilty',
#      'of',
#      'a',
#      'misdemeanor',
#      'with',
#      'a',
#      'sentence',
#      'of',
#      'six',
#      'month',
#      'in',
#      'prison',
#      'or',
#      'fine',
#      'or',
#      'both']],
#    [['now',
#      'there',
#      'we',
#      'have',
#      'specific',
#      'penalty',
#      'apply',
#      'to',
#      'that',
#      'particular',
#      'act',
#      'and',
#      'it',
#      'would',
#      'appear',
#      'that',
#      'the',
#      'general',
#      'early',
#      'provision',
#      'of',
#      'the',
#      'revised',
#      'statute',
#      'we',
#      'be',
#      'superseded',
#      'pro',
#      'tanto']],
#    [['again',
#      'in',
#      'when',
#      'that',
#      'corporation',
#      'exercise',
#      'tax',
#      'of',
#      'that',
#      'year',
#      'measure',
#      'by',
#      'corporate',
#      'income',
#      'be',
#      'pass',
#      'it',
#      'have',
#      'pass',
#      'specific',
#      'penalty',
#      'for',
#      'the',
#      'making',
#      'of',
#      'a',
#      'fraudulent',
#      'false',
#      'or',
#      'fraudulent',
#      'return',
#      'with',
#      'intent',
#      'to',
#      'defeat',
#      'the',
#      'assessment',
#      'of',
#      'one',
#      'year',
#      'in',
#      'prison',
#      'or',
#      'fine',
#      'which',
#      'incidentally',
#      'with',
#      'the',
#      'same',
#      'penalty',
#      'as',
#      'those',
#      'in',
#      'the',
#      'of',
#      'the',
#      'revise',
#      'statute']],
#    [['in',
#      'the',
#      'revenue',
#      'act',
#      'of',
#      'which',
#      'be',
#      'the',
#      'first',
#      'of',
#      'the',
#      'various',
#      'revenue',
#      'act',
#      'that',
#      'follow',
#      'thereafter',
#      'and',
#      'from',
#      'to',
#      'about',
#      'until',
#      'it',
#      'be',
#      'the',
#      'practice',
#      'of',
#      'congress',
#      'to',
#      'enact',
#      'a',
#      'new',
#      'revenue',
#      'act',
#      'about',
#      'every',
#      'two',
#      'year']],
#    [['each',
#      'of',
#      'those',
#      'act',
#      'would',
#      'be',
#      'a',
#      'complete',
#      'reenactment',
#      'of',
#      'the',
#      'income',
#      'tax',
#      'law',
#      'as',
#      'they',
#      'have',
#      'exist',
#      'up',
#      'to',
#      'that',
#      'time']],
#    [['in',
#      'the',
#      'revenue',
#      'act',
#      'of',
#      'the',
#      'first',
#      'of',
#      'such',
#      'act',
#      'congress',
#      'provide',
#      'that',
#      'whoever',
#      'make',
#      'a',
#      'false',
#      'or',
#      'fraudulent',
#      'return',
#      'with',
#      'intent',
#      'to',
#      'defeat',
#      'the',
#      'assessment',
#      'would',
#      'be',
#      'guilty',
#      'of',
#      'a',
#      'misdemeanor',
#      'and',
#      'subject',
#      'to',
#      'a',
#      'year',
#      'in',
#      'the',
#      'prison',
#      'on',
#      'a',
#      'fine']],
#    [['the',
#      'fine',
#      'in',
#      'this',
#      'in',
#      'that',
#      'act',
#      'the',
#      'be',
#      'great',
#      'than',
#      'the',
#      'fine',
#      'impose',
#      'by',
#      'section',
#      'of',
#      'the',
#      'revise',
#      'statute']],
#    [['and',
#      'we',
#      'think',
#      'that',
#      'that',
#      'indicate',
#      'that',
#      'the',
#      'specific',
#      'penalty',
#      'of',
#      'that',
#      'particular',
#      'act',
#      'be',
#      'intend',
#      'to',
#      'apply',
#      'to',
#      'the',
#      'crime',
#      'of',
#      'income',
#      'tax',
#      'evasion',
#      'rather',
#      'than',
#      'the',
#      'more',
#      'general',
#      'provision',
#      'carry',
#      'a',
#      'less',
#      'penalty']],
#    [['the',
#      'revenue',
#      'act',
#      'of',
#      'have',
#      'the',
#      'same',
#      'provision',
#      'as',
#      'to',
#      'a',
#      'false',
#      'and',
#      'fraudulent',
#      'return',
#      'with',
#      'intent',
#      'to',
#      'defeat',
#      'an',
#      'assessment',
#      'and',
#      'add',
#      'a',
#      'new',
#      'provision',
#      'make',
#      'it',
#      'a',
#      'misdemeanor',
#      'to',
#      'evade',
#      'or',
#      'attempt',
#      'to',
#      'evade',
#      'a',
#      'tax',
#      'in',
#      'any',
#      'manner']],
#    [['in',
#      'the',
#      'revenue',
#      'act',
#      'of',
#      'the',
#      'law',
#      'for',
#      'the',
#      'first',
#      'time',
#      'prescribe',
#      'an',
#      'attempt',
#      'to',
#      'evade',
#      'tax',
#      'in',
#      'any',
#      'manner',
#      'and',
#      'we',
#      'believe',
#      'that',
#      'the',
#      'addition',
#      'of',
#      'the',
#      'word',
#      'in',
#      'any',
#      'manner',
#      'in',
#      'that',
#      'act',
#      'make',
#      'it',
#      'unnecessary',
#      'for',
#      'the',
#      'law',
#      'of',
#      'any',
#      'further',
#      'to',
#      'have',
#      'reference',
#      'to',
#      'the',
#      'evasion',
#      'and',
#      'to',
#      'the',
#      'filing',
#      'of',
#      'the',
#      'false',
#      'or',
#      'fraudulent',
#      'return']],
#    [['and',
#      'significantly',
#      'the',
#      'that',
#      'term',
#      'be',
#      'drop',
#      'in',
#      'the',
#      'act',
#      'and',
#      'be',
#      'not',
#      'appear',
#      'in',
#      'any',
#      'revenue',
#      'act',
#      'since',
#      'that',
#      'time']],
#    [['in',
#      'the',
#      'revenue',
#      'act',
#      'of',
#      'the',
#      'congress',
#      'raise',
#      'the',
#      'penalty',
#      'for',
#      'a',
#      'willful',
#      'evasion',
#      'of',
#      'income',
#      'tax',
#      'from',
#      'a',
#      'misdemeanor',
#      'to',
#      'a',
#      'felony']],
#    [['and',
#      'from',
#      'that',
#      'time',
#      'until',
#      'the',
#      'successive',
#      'revenue',
#      'act',
#      'have',
#      'prescribe',
#      'an',
#      'attempt',
#      'to',
#      'evade',
#      'income',
#      'tax',
#      'as',
#      'a',
#      'felony',
#      'with',
#      'no',
#      'material',
#      'change',
#      'in',
#      'the',
#      'wording',
#      'of',
#      'a',
#      'statute']]]],
#  ['felixfrankfurter',
#   [[['but',
#      'it',
#      'but',
#      'it',
#      'be',
#      'still',
#      'one',
#      'year',
#      'the',
#      'punishment',
#      'after']]]],
#  ['charleskrice', [[['be', 'five', 'year']]]],
#  ['felixfrankfurter', [[['five', 'year', 'yes']]]],
#  ['charleskrice', [[['and', 'it', 'continue', 'that', 'way', 'in', 'each']]]],
#  ['felixfrankfurter',
#   [[['then', 'you', 'say', 'a', 'a', 'felony', 'do', 'not', 'just']]]],
#  ['charleskrice', [[['yes', 'make', 'a', 'felony']]]],
#  ['felixfrankfurter',
#   [[['a',
#      'different',
#      'voice',
#      'overlap',
#      'put',
#      'a',
#      'different',
#      'punishment',
#      'on',
#      'it']]]],
#  ['charleskrice',
#   [[['yes', 'that', 'be', 'right', 'your', 'honor']],
#    [['in',
#      'that',
#      'bring',
#      'us',
#      'to',
#      'which',
#      'the',
#      'in',
#      'the',
#      'year',
#      'in',
#      'which',
#      'the',
#      'internal',
#      'revenue',
#      'code',
#      'of',
#      'that',
#      'year',
#      'be',
#      'adopt']],
#    [['that',
#      'code',
#      'be',
#      'to',
#      'be',
#      'distinguish',
#      'from',
#      'the',
#      'internal',
#      'revenue',
#      'code',
#      'in',
#      'that',
#      'it',
#      'do',
#      'not',
#      'purport',
#      'to',
#      'be',
#      'in',
#      'any',
#      'sense',
#      'a',
#      'do',
#      'not',
#      'change',
#      'the',
#      'law',
#      'in',
#      'any',
#      'respect']],
#    [['it',
#      'be',
#      'merely',
#      'bring',
#      'together',
#      'as',
#      'the',
#      'legislator',
#      'say',
#      'into',
#      'one',
#      'volume',
#      'law',
#      'that',
#      'have',
#      'be',
#      'scatter',
#      'through',
#      'a',
#      'number',
#      'of',
#      'volume']],
#    [['and',
#      'the',
#      'fear',
#      'of',
#      'the',
#      'legislator',
#      'as',
#      'indicate',
#      'in',
#      'the',
#      'legislative',
#      'history',
#      'be',
#      'that',
#      'some',
#      'change',
#      'in',
#      'the',
#      'law',
#      'might',
#      'be',
#      'make',
#      'inadvertently',
#      'most',
#      'of',
#      'the',
#      'discussion',
#      'on',
#      'the',
#      'congressional',
#      'record',
#      'relate',
#      'to',
#      'whether',
#      'those',
#      'fear',
#      'on',
#      'the',
#      'laying',
#      'of',
#      'those',
#      'fear',
#      'for',
#      'the',
#      'sponsor',
#      'that',
#      'no',
#      'change',
#      'have',
#      'be',
#      'make',
#      'in',
#      'the',
#      'revenue',
#      'law',
#      'that',
#      'exist',
#      'prior',
#      'to',
#      'that',
#      'time']],
#    [['of',
#      'course',
#      'that',
#      'be',
#      'not',
#      'true',
#      'at',
#      'all',
#      'in',
#      'the',
#      'code',
#      'which',
#      'incorporate',
#      'any',
#      'number',
#      'of',
#      'amendment']],
#    [['but',
#      'this',
#      'be',
#      'merely',
#      'a',
#      'compilation',
#      'and',
#      'somewhat',
#      'along',
#      'the',
#      'line',
#      'of',
#      'the',
#      'change',
#      'in',
#      'the',
#      'judicial',
#      'code',
#      'or',
#      'refer',
#      'to',
#      'by',
#      'this',
#      'court',
#      'in',
#      'the',
#      'fourco',
#      'glass',
#      'company',
#      'case',
#      'here',
#      'earlier',
#      'in',
#      'this',
#      'term']]]],
#  ['felixfrankfurter',
#   [[['be', 'there', 'anything', 'turn', 'on', 'the', 'code']]]],
#  ['charleskrice',
#   [[['well',
#      'we',
#      'want',
#      'to',
#      'show',
#      'that',
#      'because',
#      'that',
#      'the',
#      'bringing',
#      'of',
#      'section',
#      'of',
#      'the',
#      'revise',
#      'statute',
#      'into',
#      'the',
#      'code',
#      'and',
#      'label',
#      'it',
#      'do',
#      'not',
#      'mean',
#      'that',
#      'there',
#      'be',
#      'any',
#      'change',
#      'in',
#      'the',
#      'scope',
#      'or',
#      'ambit',
#      'of',
#      'the',
#      'section',
#      'as',
#      'it',
#      'have',
#      'exist',
#      'prior',
#      'to',
#      'that',
#      'time']]]],
#  ['felixfrankfurter',
#   [[['that',
#      'be',
#      'that',
#      'presuppose',
#      'of',
#      'do',
#      'that',
#      'mean',
#      'any',
#      'more',
#      'than',
#      'that',
#      'if',
#      'you',
#      'be',
#      'right',
#      'if',
#      'the',
#      'government',
#      'be',
#      'right',
#      'as',
#      'to',
#      'what',
#      'as',
#      'to',
#      'the',
#      'construction',
#      'of',
#      'the',
#      'predecessor',
#      'provision',
#      'of',
#      'b',
#      'in',
#      'the',
#      'annual',
#      'or',
#      'biannuals',
#      'of',
#      'congressional',
#      'legislation',
#      'do',
#      'not',
#      'effectuate']]]],
#  ['charleskrice', [[['yes']], [['that', 'be', 'right']]]],
#  ['felixfrankfurter',
#   [[['but',
#      'you',
#      'have',
#      'to',
#      'establish',
#      'the',
#      'relationship',
#      'of',
#      'the',
#      'two',
#      'section',
#      'prior',
#      'to']]]],
#  ['charleskrice',
#   [[['yes', 'that', 'be', 'right', 'sir']],
#    [['we',
#      'think',
#      'that',
#      'a',
#      'comparison',
#      'of',
#      'the',
#      'section',
#      'with',
#      'other',
#      'statute',
#      'in',
#      'pari',
#      'materia',
#      'throughout',
#      'the',
#      'code',
#      'and',
#      'outside',
#      'of',
#      'the',
#      'internal',
#      'revenue',
#      'code',
#      'will',
#      'indicate',
#      'the',
#      'ludicrous',
#      'and',
#      'almost',
#      'absurd',
#      'result',
#      'which',
#      'would',
#      'follow',
#      'if',
#      'it',
#      'we',
#      'be',
#      'to',
#      'be',
#      'deem',
#      'that',
#      'the',
#      'following',
#      'of',
#      'a',
#      'false',
#      'and',
#      'fraudulent',
#      'return',
#      'with',
#      'intent',
#      'to',
#      'evade',
#      'tax',
#      'amount',
#      'to',
#      'no',
#      'more',
#      'than',
#      'a',
#      'felony']],
#    [['for',
#      'example',
#      'take',
#      'section',
#      'a',
#      'of',
#      'the',
#      'code',
#      'which',
#      'relate',
#      'to',
#      'act',
#      'of',
#      'omission',
#      'of',
#      'a',
#      'failure',
#      'to',
#      'file',
#      'a',
#      'return',
#      'or',
#      'to',
#      'furnish',
#      'information']],
#    [['under',
#      'that',
#      'section',
#      'the',
#      'penalty',
#      'be',
#      'one',
#      'year',
#      'in',
#      'jail',
#      'with',
#      'a',
#      'fine']],
#    [['but',
#      'if',
#      'the',
#      'petitioner',
#      'be',
#      'right',
#      'that',
#      'the',
#      'offense',
#      'he',
#      'commit',
#      'be',
#      'only',
#      'a',
#      'misdemeanor',
#      'his',
#      'act',
#      'of',
#      'omission',
#      'would',
#      'result',
#      'in',
#      'a',
#      'year',
#      'in',
#      'jail',
#      'and',
#      'a',
#      'fine',
#      'or',
#      'substantially',
#      'less',
#      'penalty',
#      'than',
#      'the',
#      'act',
#      'of',
#      'omission']],
#    [['again', 'with', 'respect', 'to', 'section', 'of', 'the', 'code']]]],
#  ['earlwarren', [[['you', 'may', 'finish', 'your', 'sentence']]]],
#  ['charleskrice',
#   [[['with',
#      'respect',
#      'to',
#      'section',
#      'of',
#      'the',
#      'code',
#      'which',
#      'prescribe',
#      'the',
#      'willful',
#      'aiding',
#      'or',
#      'assist',
#      'in',
#      'the',
#      'preparation',
#      'of',
#      'a',
#      'false',
#      'or',
#      'fraudulent',
#      'return',
#      'if',
#      'the',
#      'petitioner',
#      'be',
#      'correct',
#      'in',
#      'his',
#      'position',
#      'the',
#      'person',
#      'who',
#      'assist',
#      'in',
#      'the',
#      'filing',
#      'preparation',
#      'and',
#      'filing',
#      'of',
#      'such',
#      'a',
#      'return',
#      'will',
#      'receive',
#      'a',
#      'penalty',
#      'of',
#      'five',
#      'year',
#      'in',
#      'jail',
#      'and',
#      'a',
#      'finebut',
#      'the',
#      'one',
#      'who',
#      'actually',
#      'file',
#      'the',
#      'return',
#      'receive',
#      'only',
#      'one',
#      'year',
#      'and',
#      'fine']]]],
#  ['peterbatwood',
#   [[['mr', 'chief', 'justice', 'may', 'it', 'please', 'the', 'court']]]],
#  ['earlwarren', [[['mr', 'atwood']]]],
#  ['peterbatwood',
#   [[['i', 'have', 'just', 'a', 'few', 'remark', 'to', 'make']],
#    [['they',
#      'deal',
#      'principally',
#      'with',
#      'the',
#      'what',
#      'i',
#      'consider',
#      'there',
#      'and',
#      'then',
#      'in',
#      'the',
#      'administrative',
#      'approval',
#      'on',
#      'the',
#      'part',
#      'of',
#      'congress',
#      'in',
#      'reenact',
#      'section',
#      'a',
#      'in',
#      'the',
#      'code',
#      'of',
#      'section',
#      'of',
#      'the',
#      'code']],
#    [['when',
#      'congress',
#      'do',
#      'that',
#      'as',
#      'i',
#      'mention',
#      'in',
#      'my',
#      'early',
#      'argument',
#      'specifically',
#      'state',
#      'that',
#      'it',
#      'be',
#      'not',
#      'change',
#      'exist',
#      'law',
#      'and',
#      'congress',
#      'of',
#      'course',
#      'must',
#      'have',
#      'be',
#      'aware',
#      'of',
#      'the',
#      'fact',
#      'that',
#      'the',
#      'government',
#      'have',
#      'be',
#      'prosecute',
#      'for',
#      'more',
#      'than',
#      'two',
#      'year',
#      'prior',
#      'to',
#      'the',
#      'revenue',
#      'act',
#      'of',
#      'many',
#      'case',
#      'under',
#      'section',
#      'a',
#      'for',
#      'income',
#      'tax',
#      'violation']],
#    [['I',
#      'have',
#      'also',
#      'point',
#      'out',
#      'that',
#      'as',
#      'far',
#      'back',
#      'as',
#      'in',
#      'the',
#      'noveck',
#      'case',
#      'the',
#      'government',
#      'argue',
#      'that',
#      'section',
#      'a',
#      'be',
#      'not',
#      'applicable',
#      'to',
#      'income',
#      'tax',
#      'but',
#      'it',
#      'be',
#      'nevertheless',
#      'proceed',
#      'over',
#      'a',
#      'period',
#      'of',
#      'year',
#      'in',
#      'many',
#      'case',
#      'to',
#      'argue',
#      'that',
#      'it',
#      'be',
#      'applicable']],
#    [['in',
#      'the',
#      'case',
#      'I',
#      'have',
#      'cite',
#      'at',
#      'page',
#      'of',
#      'my',
#      'reply',
#      'brief',
#      'and',
#      'there',
#      'be',
#      'many',
#      'case',
#      'there',
#      'I',
#      'have',
#      'cite']],
#    [['and',
#      'of',
#      'course',
#      'as',
#      'late',
#      'as',
#      'in',
#      'the',
#      'inaudible',
#      'case',
#      'the',
#      'government',
#      'argue',
#      'that',
#      'it',
#      'be',
#      'applicable']],
#    [['certainly',
#      'in',
#      'those',
#      'case',
#      'the',
#      'government',
#      'be',
#      'of',
#      'course',
#      'consistent',
#      'throughout',
#      'that',
#      'period',
#      'of',
#      'time',
#      'in',
#      'the',
#      'time',
#      'when',
#      'say',
#      'it',
#      'be',
#      'applicable']],
#    [['in',
#      'any',
#      'simple',
#      'reading',
#      'of',
#      'section',
#      'a',
#      'would',
#      'indicate',
#      'that',
#      'it',
#      'be',
#      'applicable']],
#    [['absent',
#      'this',
#      'detailed',
#      'history',
#      'which',
#      'they',
#      'now',
#      'say',
#      'mean',
#      'that',
#      'it',
#      'be',
#      'inapplicable',
#      'income',
#      'tax']]]],
#  ['felixfrankfurter',
#   [[['that',
#      'congress',
#      'do',
#      'in',
#      'your',
#      'view',
#      'have',
#      'any',
#      'function',
#      'at',
#      'all']],
#    [['do',
#      'it',
#      'apply',
#      'to',
#      'a',
#      'situation',
#      'at',
#      'all',
#      'in',
#      'the',
#      'protection',
#      'of',
#      'the',
#      'revenue']]]],
#  ['peterbatwood', [[['mr', 'justice']]]],
#  ['felixfrankfurter',
#   [[['if',
#      'b',
#      'should',
#      'have',
#      'sow',
#      'the',
#      'field',
#      'with',
#      'reference',
#      'to',
#      'income',
#      'tax']]]],
#  ['peterbatwood',
#   [[['i',
#      'feel',
#      'this',
#      'way',
#      'mr',
#      'justice',
#      'frankfurter',
#      'that',
#      'it',
#      'supplement',
#      'section',
#      'b',
#      'in',
#      'that',
#      'it',
#      'provide',
#      'a',
#      'less',
#      'penalty',
#      'for',
#      'what',
#      'congress',
#      'may',
#      'have',
#      'think',
#      'be',
#      'a',
#      'small',
#      'offense']]]],
#  ['felixfrankfurter',
#   [[['i', 'understand', 'that']],
#    [['that', 'it', 'i', 'understand', 'that']],
#    [['what',
#      'i',
#      'want',
#      'to',
#      'know',
#      'be',
#      'assume',
#      'b',
#      'be',
#      'to',
#      'be',
#      'give',
#      'the',
#      'restrictive',
#      'and',
#      'exclusive',
#      'scope',
#      'that',
#      'be',
#      'now',
#      'contend',
#      'for',
#      'by',
#      'the',
#      'government']],
#    [['would',
#      'go',
#      'to',
#      'sleep',
#      'and',
#      'have',
#      'no',
#      'incident',
#      'at',
#      'all']]]],
#  ['peterbatwood',
#   [[['i',
#      'think',
#      'that',
#      'would',
#      'be',
#      'the',
#      'effect',
#      'of',
#      'it',
#      'yes']]]],
#  ['felixfrankfurter',
#   [[['well',
#      'as',
#      'to',
#      'these',
#      'thing',
#      'but',
#      'would',
#      'not',
#      'they',
#      'would',
#      'it',
#      'apply',
#      'to',
#      'other',
#      'situation']]]],
#  ['peterbatwood', [[['in', 'then']]]],
#  ['felixfrankfurter',
#   [[['for', 'me', 'it', 'must', 'be', 'a', 'very', 'strong', 'argument']]]],
#  ['peterbatwood', [[['i', 'think', 'it', 'would']]]],
#  ['felixfrankfurter',
#   [[['if', 'it', 'we', 'be', 'to', 'exist', 'voice', 'overlap']]]],
#  ['peterbatwood',
#   [[['i',
#      'think',
#      'it',
#      'would',
#      'still',
#      'exist',
#      'because',
#      'as',
#      'section',
#      'applies',
#      'to',
#      'false',
#      'testimony',
#      'and',
#      'applies',
#      'to',
#      'failure',
#      'to',
#      'give',
#      'produce',
#      'record',
#      'and',
#      'all',
#      'those',
#      'thing',
#      'which',
#      'do',
#      'apply',
#      'to',
#      'income',
#      'tax']]]],
#  ['felixfrankfurter', [[['i', 'do', 'not', 'think']]]],
#  ['peterbatwood', [[['i', 'do', 'not', 'know', 'whether', 'it', 'follow']]]],
#  ['felixfrankfurter', [[['I', 'have', 'put', 'my', 'question']]]],
#  ['peterbatwood', [[['yes']]]],
#  ['felixfrankfurter',
#   [[['would',
#      'there',
#      'be',
#      'no',
#      'set',
#      'of',
#      'circumstance',
#      'to',
#      'which',
#      'could',
#      'be',
#      'apply',
#      'to',
#      'which',
#      'b',
#      'would',
#      'not',
#      'apply']]]],
#  ['peterbatwood',
#   [[['i', 'can', 'not', 'think', 'of', 'any', 'now']],
#    [['i',
#      'think',
#      'it',
#      'would',
#      'be',
#      'ineffective',
#      'when',
#      'apply',
#      'anything',
#      'accord',
#      'to',
#      'the',
#      'government',
#      's',
#      'argument']]]],
#  ['felixfrankfurter',
#   [[['well',
#      'i',
#      'think',
#      'for',
#      'me',
#      'it',
#      'be',
#      'a',
#      'very',
#      'important',
#      'point']]]],
#  ['peterbatwood', [[['yes', 'sir']]]],
#  ['felixfrankfurter',
#   [[['it',
#      'be',
#      'one',
#      'thing',
#      'to',
#      'say',
#      'that',
#      'the',
#      'government',
#      'be',
#      'argue',
#      'for',
#      'a',
#      'construction',
#      'that',
#      'would',
#      'wipe',
#      'out',
#      'a',
#      'section',
#      'quite',
#      'a',
#      'different',
#      'argument',
#      'to',
#      'say',
#      'that',
#      'there',
#      'be',
#      'two',
#      'section',
#      'which',
#      'have',
#      'separate',
#      'sphere',
#      'of',
#      'activity']]]],
#  ['peterbatwood',
#   [[['i',
#      'do',
#      'not',
#      'think',
#      'the',
#      'argument',
#      'have',
#      'have',
#      'a',
#      'separate',
#      'sphere',
#      'of',
#      'activity']]]],
#  ['felixfrankfurter', [[['well', 'as', 'i', 'understand', 'they', 'do']]]],
#  ['peterbatwood', [[['the', 'argument', 'be', 'repeal']]]],
#  ['felixfrankfurter', [[['pardon', 'me']]]],
#  ['peterbatwood', [[['they', 'they', 'argue', 'i', 'believe']]]],
#  ['felixfrankfurter',
#   [[['we',
#      'deal',
#      'as',
#      'to',
#      'what',
#      'b',
#      'cover',
#      'but',
#      'not',
#      'as',
#      'to',
#      'everything']],
#    [['it',
#      'be',
#      'not',
#      'an',
#      'empty',
#      'thing',
#      'thereafter',
#      'a',
#      'collection',
#      'of',
#      'word',
#      'with',
#      'no',
#      'nothing',
#      'on',
#      'which',
#      'you',
#      'can',
#      'talk']]]],
#  ['peterbatwood',
#   [[['i',
#      'rely',
#      'on',
#      'the',
#      'fact',
#      'that',
#      'the',
#      'government',
#      'be',
#      'prosecute',
#      'for',
#      'many',
#      'year',
#      'under',
#      'section',
#      'a',
#      'and',
#      'congress',
#      'know',
#      'that',
#      'and',
#      'reenact',
#      'section',
#      'a',
#      'as',
#      'part',
#      'of',
#      'of',
#      'the',
#      'revenue',
#      'act',
#      'of',
#      'which',
#      'clearly',
#      'deal',
#      'with',
#      'income',
#      'tax']]]],
#  ['hugolblack', [[['you', 'say', 'for', 'many', 'year', 'what']]]],
#  ['peterbatwood',
#   [[['that',
#      'be',
#      'from',
#      'to',
#      'and',
#      'then',
#      'in',
#      'the',
#      'prior',
#      'year',
#      'the',
#      'in',
#      'the',
#      'many',
#      'case',
#      'which',
#      'I',
#      'have',
#      'cite',
#      'at',
#      'page',
#      'of',
#      'my',
#      'brief',
#      'they',
#      'argue',
#      'that',
#      'it',
#      'be',
#      'applicable',
#      'to',
#      'income',
#      'tax',
#      'and',
#      'congress',
#      'presume',
#      'they',
#      'could',
#      'be',
#      'aware',
#      'of',
#      'that',
#      'argument']],
#    [['thank', 'you']]]]]

# %% [markdown]
# ## Filtering down to just the petitioner words

# %% [markdown]
# I need just the words said by the petitioner for my question. Here Im using a custom function I made that gets only the words said by the petitioner or the justice in response to the petitioner.

# %%
justices = pd.read_csv('../data/justices.csv', header = None) # Importing a list of justices for my filtering process

# %%
justices = list(justices[0])

# %%
justices = [x.lower().replace(" ", "").replace('.', '').replace(',','').replace('jr', '') for x in justices]
# doing a little bit of cleaning on the justices file

# %%
#testing my function
src.get_lawyers(speaker_cleanText["353 US 373 (1957)"], justices) #testing my custom function for grabbing the lawyer names
# Out:
# ['charleskrice', 'peterbatwood']

# %%
#testing out a similar function that gets the justices
src.get_justices(speaker_cleanText["353 US 373 (1957)"], justices)
# Out:
# ['earlwarren', 'unknown', 'hugolblack', 'felixfrankfurter', 'williamjbrennan']

# %%
#making a dictionary of only the lawyers differentiated by case
case_lawyers_dict = {}  
for case in speaker_cleanText:
    case_lawyers_dict.update({case:src.get_lawyers(speaker_cleanText[case], justices)})

# %%
#making a dictionary of the justices in each case 
justice_lawyers_dict = {} 
for case in speaker_cleanText:
    justice_lawyers_dict.update({case:src.get_justices(speaker_cleanText[case], justices)})

# %% [markdown]
# quickly scanning the names manually to double check theres no justices that snuck through, making a dataframe was unnesscary but much easier to examine visually

# %%
# and making the sure the key is what I think it is for future merges 
case_lawyers_dict['353 US 373 (1957)']
# Out:
# ['charleskrice', 'peterbatwood']

# %%
justice_lawyers_dict['353 US 373 (1957)'] #looks like good, I'll deal with the mysterious unknown justice later
# Out:
# ['earlwarren', 'unknown', 'hugolblack', 'felixfrankfurter', 'williamjbrennan']

# %% [markdown]
# ## Getting the Words Said By the Petitioners and Justices in Each Case

# %% [markdown]
# For my analysis I want only the words said by the petioners or the justices, so Im going to use my custom function to make a dictionary that has this data. I searched long and hard for a way to scrape the lawyers and advocated for each side, but there was no way to do so for a large percentage of my data. While the petitioner always speaks first, the function is imperfect as it just takes the first lawyers words and the justice responses to those words. The petitioner could have another speaker that this function would not capture, but for the purposes of NLP we can still evualaute whether the words have any predictive power.

# %%
#making the dictionary 
petitioner_words_dict = {}
for x in speaker_cleanText:
    try:
        petitioner_words_dict.update({x: src.get_petitioner_words(x, justices, case_lawyers_dict, speaker_cleanText)})
        #get_petitioner_words is a function which makes a list with the words said only by 
        #the petitioners or the justices in response
    except:
        #some of the cases do not have transcripts which breaks the function
        pass

# %%
len(petitioner_words_dict)
# Out:
# 6005

# %%
justice_words_dict = {}
for x in speaker_cleanText:
    try:
        justice_words_dict.update({x: src.get_justice_words(x, justices, case_lawyers_dict, speaker_cleanText)})
        #this does the same but only for the justice words said in response t0 or to the petitioner 
    except:
        pass

# %%
src.get_cases("ruthbaderginsburg", speaker_cleanText, justice_lawyers_dict)
# Out:
# ['406\xa0US\xa0320\xa0(1972)',
#  '411\xa0US\xa0677\xa0(1973)',
#  '416\xa0US\xa0351\xa0(1974)',
#  '421\xa0US\xa0772\xa0(1975)',
#  '420\xa0US\xa0636\xa0(1975)',
#  '430\xa0US\xa0199\xa0(1977)',
#  '439\xa0US\xa0357\xa0(1979)',
#  '512\xa0US\xa0374\xa0(1993)',
#  '511\xa0US\xa0462\xa0(1994)',
#  '510\xa0US\xa0163\xa0(1994)',
#  '511\xa0US\xa0350\xa0(1994)',
#  '510\xa0US\xa0332\xa0(1994)',
#  '511\xa0US\xa01\xa0(1994)',
#  '512\xa0US\xa0821\xa0(1994)',
#  '511\xa0US\xa0658\xa0(1994)',
#  '511\xa0US\xa0738\xa0(1994)',
#  '512\xa0US\xa0477\xa0(1994)',
#  '512\xa0US\xa061\xa0(1994)',
#  '510\xa0US\xa027\xa0(1993)',
#  '510\xa0US\xa0487\xa0(1994)',
#  '510\xa0US\xa0517\xa0(1994)',
#  '511\xa0US\xa0244\xa0(1994)',
#  '512\xa0US\xa0339\xa0(1994)',
#  '510\xa0US\xa0510\xa0(1994)',
#  '510\xa0US\xa07\xa0(1993)',
#  '510\xa0US\xa042\xa0(1993)',
#  '512\xa0US\xa0622\xa0(1994)',
#  '512\xa0US\xa0186\xa0(1994)',
#  '510\xa0US\xa017\xa0(1993)',
#  '510\xa0US\xa0249\xa0(1994)',
#  '511\xa0US\xa0431\xa0(1994)',
#  '511\xa0US\xa0127\xa0(1994)',
#  '511\xa0US\xa0485\xa0(1994)',
#  '510\xa0US\xa0355\xa0(1994)',
#  '510\xa0US\xa0471\xa0(1994)',
#  '511\xa0US\xa0531\xa0(1994)',
#  '512\xa0US\xa0374\xa0(1994)',
#  '512\xa0US\xa043\xa0(1994)',
#  '512\xa0US\xa0849\xa0(1994)',
#  '511\xa0US\xa0117\xa0(1994)',
#  '511\xa0US\xa0202\xa0(1994)',
#  '511\xa0US\xa0661\xa0(1994)',
#  '510\xa0US\xa0443\xa0(1994)',
#  '512\xa0US\xa0753\xa0(1994)',
#  '511\xa0US\xa039\xa0(1994)',
#  '511\xa0US\xa0328\xa0(1994)',
#  '510\xa0US\xa0383\xa0(1994)',
#  '511\xa0US\xa0222\xa0(1994)',
#  '511\xa0US\xa0863\xa0(1994)',
#  '535\xa0US\xa0743\xa0(2002)',
#  '535\xa0US\xa0137\xa0(2002)',
#  '534\xa0US\xa0362\xa0(2002)',
#  '536\xa0US\xa0129\xa0(2002)',
#  '536\xa0US\xa073\xa0(2002)',
#  '535\xa0US\xa0212\xa0(2002)',
#  '534\xa0US\xa0246\xa0(2002)',
#  '536\xa0US\xa0452\xa0(2002)',
#  '535\xa0US\xa0722\xa0(2002)',
#  '534\xa0US\xa0327\xa0(2002)',
#  '535\xa0US\xa0302\xa0(2002)',
#  '535\xa0US\xa081\xa0(2002)',
#  '535\xa0US\xa0613\xa0(2002)',
#  '536\xa0US\xa0273\xa0(2002)',
#  '536\xa0US\xa0355\xa0(2002)',
#  '535\xa0US\xa0425\xa0(2002)',
#  '534\xa0US\xa0516\xa0(2002)',
#  '534\xa0US\xa0204\xa0(2002)',
#  '535\xa0US\xa01\xa0(2002)',
#  '536\xa0US\xa0238\xa0(2002)',
#  '535\xa0US\xa0685\xa0(2002)',
#  '536\xa0US\xa0424\xa0(2002)',
#  '535\xa0US\xa0391\xa0(2002)',
#  '534\xa0US\xa019\xa0(2001)',
#  '535\xa0US\xa0682\xa0(2002)',
#  '536\xa0US\xa0214\xa0(2002)',
#  '535\xa0US\xa0826\xa0(2002)',
#  '535\xa0US\xa055\xa0(2002)',
#  '535\xa0US\xa0228\xa0(2002)',
#  '536\xa0US\xa0545\xa0(2002)',
#  '535\xa0US\xa0789\xa0(2002)',
#  '534\xa0US\xa0438\xa0(2002)',
#  '536\xa0US\xa0194\xa0(2002)',
#  '536\xa0US\xa0101\xa0(2002)',
#  '534\xa0US\xa0161\xa0(2002)',
#  '534\xa0US\xa0473\xa0(2002)',
#  '535\xa0US\xa043\xa0(2002)',
#  '534\xa0US\xa0506\xa0(2002)',
#  '535\xa0US\xa0654\xa0(2002)',
#  '534\xa0US\xa0316\xa0(2002)',
#  '534\xa0US\xa084\xa0(2001)',
#  '534\xa0US\xa0426\xa0(2002)',
#  '535\xa0US\xa0162\xa0(2002)',
#  '534\xa0US\xa0184\xa0(2002)',
#  '536\xa0US\xa0730\xa0(2002)',
#  '536\xa0US\xa0765\xa0(2002)',
#  '534\xa0US\xa01\xa0(2001)',
#  '534\xa0US\xa0407\xa0(2002)',
#  '536\xa0US\xa024\xa0(2002)',
#  '534\xa0US\xa0235\xa0(2002)',
#  '536\xa0US\xa0181\xa0(2002)',
#  '536\xa0US\xa0150\xa0(2002)',
#  '536\xa0US\xa0822\xa0(2002)',
#  '535\xa0US\xa0125\xa0(2002)',
#  '535\xa0US\xa0635\xa0(2002)',
#  '535\xa0US\xa0467\xa0(2002)',
#  '534\xa0US\xa0279\xa0(2002)',
#  '535\xa0US\xa0234\xa0(2002)',
#  '534\xa0US\xa0112\xa0(2001)',
#  '535\xa0US\xa0357\xa0(2002)',
#  '534\xa0US\xa061\xa0(2001)',
#  '535\xa0US\xa0813\xa0(2002)',
#  '536\xa0US\xa01\xa0(2002)',
#  '535\xa0US\xa0564\xa0(2002)',
# ## Dictionary to DataFrame and cleaning up the column titles and value

# %%
dfj = pd.DataFrame.from_dict(justice_words_dict.items()) #turning both dicts into DFs

# %%
df = pd.DataFrame.from_dict(petitioner_words_dict.items())

# %%
df.columns = ['case', 'text']
dfj.columns = ['case', 'text']

# %%
df[df.case =="353 US 373 (1957)"] #testing to make sure the rows are what I think they are
# Out:
#                  case                                               text
# 45  353 US 373 (1957)  [[[['I', 'be', 'include', 'my', 'remark', 'wit...

# %% [markdown]
# Getting rid of a bunch of punctuation

# %%
#remopving remanants of the nested list structure
df.text = df.text.apply(lambda x: str(x).replace('[','').replace(']', ''))
dfj.text = dfj.text.apply(lambda x: str(x).replace('[','').replace(']', ''))

# %%
#taking out commas
df.text = df.text.apply(lambda x: x.replace(",", ''))
dfj.text = dfj.text.apply(lambda x: x.replace(",", ''))

# %%
df.head()
# Out:
#                 case                                               text
# 0  352 US 282 (1957)  'may' 'it' 'please' 'the' 'court' 'this' 'case...
# 1  353 US 586 (1957)  'mr' 'chief' 'justice' 'if' 'the' 'court' 'ple...
# 2  352 US 599 (1957)  'mr' 'chief' 'justice' 'and' 'associate' 'just...
# 3   352 US 82 (1956)  'may' 'it' 'please' 'the' 'court' 'mr' 'willia...
# 4  352 US 220 (1957)  'may' 'it' 'please' 'the' 'court' 'mr' 'plauch...

# %%
#removing the year from the citation as its not present in my other dataset
df.case = df.case.apply(lambda x: re.sub('(\d\d\d\d)', '', x))
dfj.case = dfj.case.apply(lambda x: re.sub('(\d\d\d\d)', '', x))

# %%
#lowercase
df.case = df.case.apply(lambda x: x.lower())
dfj.case = dfj.case.apply(lambda x: x.lower())

# %% [markdown]
# ### Removing non ascii characters

# %% [markdown]
# These do not act like strings and are hard to merge on.

# %%
#My custom function for modifying the "case" colum to remove non ascii characters
df.case = df.case.apply(lambda x: src.remove_non_ascii_chars(x)) 
dfj.case = dfj.case.apply(lambda x: src.remove_non_ascii_chars(x))

# %%
df[df.case == '352us282']#this would not work if the function did not work
# Out:
#        case                                               text
# 0  352us282  'may' 'it' 'please' 'the' 'court' 'this' 'case...

# %%
#doing the same with the text but with a slightly different function
df.text = df.text.apply(lambda x: src.remove_non_ascii_chars_t(x))
dfj.text = dfj.text.apply(lambda x: src.remove_non_ascii_chars_t(x))

# %%
#other clean up after changing to ascii
df.text = df.text.apply(lambda x: x.replace("'", "" ))
dfj.text = dfj.text.apply(lambda x: x.replace("'", "" ))

# %%
#checking my work 
df.head()
# Out:
#        case                                               text
# 0  352us282  may it please the court this case be here on a...
# 1  353us586  mr chief justice if the court please when the ...
# 2  352us599  mr chief justice and associate justice of the ...
# 3   352us82  may it please the court mr williams this matte...
# 4  352us220  may it please the court mr plauche you may pro...

# %%
#and checking on the justices 
dfj.head()
# Out:
#        case                                               text
# 0  352us282  that instruction i take it in effect import in...
# 1  353us586  may i at this point ask to be declare inaudibl...
# 2  352us599  well of course of course you may yes now mr mr...
# 3   352us82  mr williams that do not mean that it be only a...
# 4  352us220  mr plauche you may proceed deny the united sta...

# %% [markdown]
# ## Importing CSV with Further Case Info and Target Variable

# %% [markdown]
# This is SCDB CSV which has all my categorical data including the target variable of whether or not the petitioner won.

# %%
#importing the CSV from the SCDB with cp1252 encoding 
df2 = pd.read_csv("../data/SCDB_2020_01_caseCentered_Citation.csv", encoding='cp1252')

# %%
df2.head()#checking it out
# Out:
#      caseId     docketId    caseIssuesId             voteId dateDecision  \
# 0  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01   11/18/1946
# 1  1946-002  1946-002-01  1946-002-01-01  1946-002-01-01-01   11/18/1946
# 2  1946-003  1946-003-01  1946-003-01-01  1946-003-01-01-01   11/18/1946
# 3  1946-004  1946-004-01  1946-004-01-01  1946-004-01-01-01   11/25/1946
# 4  1946-005  1946-005-01  1946-005-01-01  1946-005-01-01-01   11/25/1946
#
#    decisionType       usCite        sctCite       ledCite  \
# 0             1   329 U.S. 1    67 S. Ct. 6   91 L. Ed. 3
# 1             1  329 U.S. 14   67 S. Ct. 13  91 L. Ed. 12
# 2             1  329 U.S. 29    67 S. Ct. 1  91 L. Ed. 22
# 3             7  329 U.S. 40  67 S. Ct. 167  91 L. Ed. 29
# 4             1  329 U.S. 64  67 S. Ct. 154  91 L. Ed. 44
#
#               lexisCite  term  naturalCourt   chief docket  \
# 0  1946 U.S. LEXIS 1724  1946          1301  Vinson     24
# 1  1946 U.S. LEXIS 1725  1946          1301  Vinson     12
# 2  1946 U.S. LEXIS 3037  1946          1301  Vinson     21
# 3  1946 U.S. LEXIS 1696  1946          1301  Vinson     26
# 4  1946 U.S. LEXIS 2997  1946          1301  Vinson     50
#
#                                             caseName  ... voteUnclear  \
# 0  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...  ...         0.0
# 1                         CLEVELAND v. UNITED STATES  ...         0.0
# 2      CHAMPLIN REFINING CO. v. UNITED STATES ET AL.  ...         0.0
# 3   UNITED STATES v. ALCEA BAND OF TILLAMOOKS ET AL.  ...         0.0
# 4         UNITED STATES v. HOWARD P. FOLEY CO., INC.  ...         0.0
#
#      issue  issueArea  decisionDirection  decisionDirectionDissent  \
# 0  80180.0        8.0                2.0                       0.0
# 1  10500.0        1.0                1.0                       0.0
# 2  80250.0        8.0                2.0                       0.0
# 3  20150.0        2.0                2.0                       0.0
# 4  80060.0        8.0                2.0                       0.0
#
#    authorityDecision1  authorityDecision2  lawType  lawSupp         lawMinor  \
# 0                 4.0                 NaN      6.0    600.0   35 U.S.C. § 33
# 1                 4.0                 NaN      6.0    600.0  18 U.S.C. § 398
# 2                 1.0                 NaN      2.0    207.0              NaN
# 3                 4.0                 NaN      6.0    600.0     49 Stat. 801
# 4                 7.0                 NaN      NaN      NaN              NaN
#
#    majOpinWriter  majOpinAssigner  splitVote  majVotes  minVotes
# 0           78.0             78.0          1         8         1
# 1           81.0             87.0          1         6         3
# 2           84.0             78.0          1         5         4
# 3           87.0             87.0          1         5         3
# 4           78.0             87.0          1         6         3
#
# [5 rows x 53 columns]

# %% [markdown]
# ## Merging with Text DF

# %%
#grabbing only the columns I want to explore in combination with thet text data
target_name_df = df2[['partyWinning', 'usCite', 'decisionDirection', 'majVotes']].copy()#grabbing just the columns I need

# %%
# changing column names
target_name_df.columns = ['target', 'case', 'lib_or_con', 'majVotes']

# %%
#removing punctiation
target_name_df['case'] = target_name_df['case'].apply(lambda x: str(x).replace('.', '').lower().replace(' ', ''))#removing punctation

# %%
target_name_df.head()
# Out:
#    target     case  lib_or_con  majVotes
# 0     1.0   329us1         2.0         8
# 1     0.0  329us14         1.0         6
# 2     0.0  329us29         2.0         5
# 3     0.0  329us40         2.0         5
# 4     1.0  329us64         2.0         6

# %%
# testing the case variable to make sure I can merge with the text data
target_name_df[target_name_df.case == '352us282' ]
# Out:
#       target      case  lib_or_con  majVotes
# 1129     1.0  352us282         2.0         6

# %% [markdown]
# ### Merging with the Text Data

# %%
#merging on the case citation column
final_df = df.merge(target_name_df, on ='case') 
final_justice_df= dfj.merge(target_name_df, on ='case')

# %%
#filtering down to "close votes"
#final_df = final_df[final_df.majVotes < 7] # narrowing down to "close votes"
#final_justice_df = final_justice_df[final_justice_df.majVotes < 7]

# %%
final_df.head()
# Out:
#        case                                               text  target  \
# 0  352us282  may it please the court this case be here on a...     1.0
# 1  353us586  mr chief justice if the court please when the ...     1.0
# 2  352us599  mr chief justice and associate justice of the ...     0.0
# 3   352us82  may it please the court mr williams this matte...     0.0
# 4  352us220  may it please the court mr plauche you may pro...     0.0
#
#    lib_or_con  majVotes
# 0         2.0         6
# 1         2.0         4
# 2         1.0         8
# 3         2.0         8
# 4         1.0         8

# %%
final_df.target.value_counts()# checking to make sure there are enough of each class
# Out:
# 1.0    3766
# 0.0    2162
# 2.0       1
# Name: target, dtype: int64

# %%
final_df = final_df[final_df.target!= 2.0]# getting rid of the one close case wich had an undefined result
final_justice_df = final_justice_df[final_justice_df.target != 2.0]

# %%
final_df = final_df.dropna()#dropping nans that came with the categorical data 
final_justice_df = final_justice_df.dropna()

# %%
import math
#this was the most consistent way to turn floats into integers
final_df.target = final_df.target.apply(lambda x: math.trunc(x)) 
final_justice_df.target = final_justice_df.target.apply(lambda x: math.trunc(x))

# %%
final_df.target.value_counts() #checking to make sure it works
# Out:
# 1    3766
# 0    2160
# Name: target, dtype: int64

# %%
final_justice_df.target.value_counts()# theyre the same which is a good thing and makes sense
# Out:
# 1    3766
# 0    2160
# Name: target, dtype: int64

# %%
#have not kept up as much with the final justice df, lets see if we did all the steps
final_justice_df.head()
# Out:
#        case                                               text  target  \
# 0  352us282  that instruction i take it in effect import in...       1
# 1  353us586  may i at this point ask to be declare inaudibl...       1
# 2  352us599  well of course of course you may yes now mr mr...       0
# 3   352us82  mr williams that do not mean that it be only a...       0
# 4  352us220  mr plauche you may proceed deny the united sta...       0
#
#    lib_or_con  majVotes
# 0         2.0         6
# 1         2.0         4
# 2         1.0         8
# 3         2.0         8
# 4         1.0         8

# %%
final_df.to_csv('../data/Final_Merge.csv', index = False)# exporting to a csv for EDA and modeling
final_justice_df.to_csv('../data/final_justice.csv', index = False)
